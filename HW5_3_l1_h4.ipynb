# %%
import math
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import random


# -------------------------------
# 1. Data Preparation
# -------------------------------
english_to_french = [
 
    ("I am cold", "J'ai froid"),
    ("You are tired", "Tu es fatigué"),
    ("He is hungry", "Il a faim"),
    ("She is happy", "Elle est heureuse"),
    ("We are friends", "Nous sommes amis"),
    ("They are students", "Ils sont étudiants"),
    ("The cat is sleeping", "Le chat dort"),
    ("The sun is shining", "Le soleil brille"),
    ("We love music", "Nous aimons la musique"),
    ("She speaks French fluently", "Elle parle français couramment"),
    ("He enjoys reading books", "Il aime lire des livres"),
    ("They play soccer every weekend", "Ils jouent au football chaque week-end"),
    ("The movie starts at 7 PM", "Le film commence à 19 heures"),
    ("She wears a red dress", "Elle porte une robe rouge"),
    ("We cook dinner together", "Nous cuisinons le dîner ensemble"),
    ("He drives a blue car", "Il conduit une voiture bleue"),
    ("They visit museums often", "Ils visitent souvent des musées"),
    ("The restaurant serves delicious food", "Le restaurant sert une délicieuse cuisine"),
    ("She studies mathematics at university", "Elle étudie les mathématiques à l'université"),
    ("We watch movies on Fridays", "Nous regardons des films le vendredi"),
    ("He listens to music while jogging", "Il écoute de la musique en faisant du jogging"),
    ("They travel around the world", "Ils voyagent autour du monde"),
    ("The book is on the table", "Le livre est sur la table"),
    ("She dances gracefully", "Elle danse avec grâce"),
    ("We celebrate birthdays with cake", "Nous célébrons les anniversaires avec un gâteau"),
    ("He works hard every day", "Il travaille dur tous les jours"),
    ("They speak different languages", "Ils parlent différentes langues"),
    ("The flowers bloom in spring", "Les fleurs fleurissent au printemps"),
    ("She writes poetry in her free time", "Elle écrit de la poésie pendant son temps libre"),
    ("We learn something new every day", "Nous apprenons quelque chose de nouveau chaque jour"),
    ("The dog barks loudly", "Le chien aboie bruyamment"),
    ("He sings beautifully", "Il chante magnifiquement"),
    ("They swim in the pool", "Ils nagent dans la piscine"),
    ("The birds chirp in the morning", "Les oiseaux gazouillent le matin"),
    ("She teaches English at school", "Elle enseigne l'anglais à l'école"),
    ("We eat breakfast together", "Nous prenons le petit déjeuner ensemble"),
    ("He paints landscapes", "Il peint des paysages"),
    ("They laugh at the joke", "Ils rient de la blague"),
    ("The clock ticks loudly", "L'horloge tic-tac bruyamment"),
    ("She runs in the park", "Elle court dans le parc"),
    ("We travel by train", "Nous voyageons en train"),
    ("He writes a letter", "Il écrit une lettre"),
    ("They read books at the library", "Ils lisent des livres à la bibliothèque"),
    ("The baby cries", "Le bébé pleure"),
    ("She studies hard for exams", "Elle étudie dur pour les examens"),
    ("We plant flowers in the garden", "Nous plantons des fleurs dans le jardin"),
    ("He fixes the car", "Il répare la voiture"),
    ("They drink coffee in the morning", "Ils boivent du café le matin"),
    ("The sun sets in the evening", "Le soleil se couche le soir"),
    ("She dances at the party", "Elle danse à la fête"),
    ("We play music at the concert", "Nous jouons de la musique au concert"),
    ("He cooks dinner for his family", "Il cuisine le dîner pour sa famille"),
    ("They study French grammar", "Ils étudient la grammaire française"),
    ("The rain falls gently", "La pluie tombe doucement"),
    ("She sings a song", "Elle chante une chanson"),
    ("We watch a movie together", "Nous regardons un film ensemble"),
    ("He sleeps deeply", "Il dort profondément"),
    ("They travel to Paris", "Ils voyagent à Paris"),
    ("The children play in the park", "Les enfants jouent dans le parc"),
    ("She walks along the beach", "Elle se promène le long de la plage"),
    ("We talk on the phone", "Nous parlons au téléphone"),
    ("He waits for the bus", "Il attend le bus"),
    ("They visit the Eiffel Tower", "Ils visitent la tour Eiffel"),
    ("The stars twinkle at night", "Les étoiles scintillent la nuit"),
    ("She dreams of flying", "Elle rêve de voler"),
    ("We work in the office", "Nous travaillons au bureau"),
    ("He studies history", "Il étudie l'histoire"),
    ("They listen to the radio", "Ils écoutent la radio"),
    ("The wind blows gently", "Le vent souffle doucement"),
    ("She swims in the ocean", "Elle nage dans l'océan"),
    ("We dance at the wedding", "Nous dansons au mariage"),
    ("He climbs the mountain", "Il gravit la montagne"),
    ("They hike in the forest", "Ils font de la randonnée dans la forêt"),
    ("The cat meows loudly", "Le chat miaule bruyamment"),
    ("She paints a picture", "Elle peint un tableau"),
    ("We build a sandcastle", "Nous construisons un château de sable"),
    ("He sings in the choir", "Il chante dans le chœur"),
    ("They ride bicycles", "Ils font du vélo"),
    ("The coffee is hot", "Le café est chaud"),
    ("She wears glasses", "Elle porte des lunettes"),
    ("We visit our grandparents", "Nous rendons visite à nos grands-parents"),
    ("He plays the guitar", "Il joue de la guitare"),
    ("They go shopping", "Ils font du shopping"),
    ("The teacher explains the lesson", "Le professeur explique la leçon"),
    ("She takes the train to work", "Elle prend le train pour aller au travail"),
    ("We bake cookies", "Nous faisons des biscuits"),
    ("He washes his hands", "Il se lave les mains"),
    ("They enjoy the sunset", "Ils apprécient le coucher du soleil"),
    ("The river flows calmly", "La rivière coule calmement"),
    ("She feeds the cat", "Elle nourrit le chat"),
    ("We visit the museum", "Nous visitons le musée"),
    ("He fixes his bicycle", "Il répare son vélo"),
    ("They paint the walls", "Ils peignent les murs"),
    ("The baby sleeps peacefully", "Le bébé dort paisiblement"),
    ("She ties her shoelaces", "Elle attache ses lacets"),
    ("We climb the stairs", "Nous montons les escaliers"),
    ("He shaves in the morning", "Il se rase le matin"),
    ("They set the table", "Ils mettent la table"),
    ("The airplane takes off", "L'avion décolle"),
    ("She waters the plants", "Elle arrose les plantes"),
    ("We practice yoga", "Nous pratiquons le yoga"),
    ("He turns off the light", "Il éteint la lumière"),
    ("They play video games", "Ils jouent aux jeux vidéo"),
    ("The soup smells delicious", "La soupe sent délicieusement bon"),
    ("She locks the door", "Elle ferme la porte à clé"),
    ("We enjoy a picnic", "Nous profitons d'un pique-nique"),
    ("He checks his email", "Il vérifie ses emails"),
    ("They go to the gym", "Ils vont à la salle de sport"),
    ("The moon shines brightly", "La lune brille intensément"),
    ("She catches the bus", "Elle attrape le bus"),
    ("We greet our neighbors", "Nous saluons nos voisins"),
    ("He combs his hair", "Il se peigne les cheveux"),
    ("They wave goodbye", "Ils font un signe d'adieu")
 
]



SOS_token = 0
EOS_token = 1




all_words = set()
for eng, fre in english_to_french:
    all_words.update(eng.split())
    all_words.update(fre.split())
all_words = sorted(list(all_words))
word_to_index = {"SOS": SOS_token, "EOS": EOS_token}
for i, word in enumerate(all_words):
    word_to_index[word] = i + 2
index_to_word = {index: word for word, index in word_to_index.items()}




class TranslationDataset(Dataset):
    def __init__(self, data, word_to_index):
        self.data = data
        self.word_to_index = word_to_index


    def __len__(self):
        return len(self.data)


    def __getitem__(self, idx):
        src_sentence, tgt_sentence = self.data[idx]
        src_tensor = torch.tensor([self.word_to_index[word] for word in src_sentence.split()] + [EOS_token], dtype=torch.long)
        tgt_tensor = torch.tensor([self.word_to_index[word] for word in tgt_sentence.split()] + [EOS_token], dtype=torch.long)
        return src_tensor, tgt_tensor




dataset = TranslationDataset(english_to_french, word_to_index)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")




class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=100):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)  # even indices
        pe[:, 1::2] = torch.cos(position * div_term)  # odd indices
        pe = pe.unsqueeze(1)  # (max_len, 1, d_model)
        self.register_buffer('pe', pe)


    def forward(self, x):
        # x: (seq_len, batch_size, d_model)
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)




def generate_square_subsequent_mask(sz):
    mask = torch.triu(torch.ones(sz, sz), diagonal=1)
    mask = mask.masked_fill(mask == 1, float('-inf'))
    return mask




class TransformerTranslationModel(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_layers, dim_feedforward=512, dropout=0.1):
        super(TransformerTranslationModel, self).__init__()
        self.d_model = d_model
        self.src_embedding = nn.Embedding(vocab_size, d_model)
        self.tgt_embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model, dropout)
        self.pos_decoder = PositionalEncoding(d_model, dropout)
        self.transformer = nn.Transformer(d_model=d_model, nhead=nhead,
                                          num_encoder_layers=num_layers,
                                          num_decoder_layers=num_layers,
                                          dim_feedforward=dim_feedforward,
                                          dropout=dropout)
        self.fc_out = nn.Linear(d_model, vocab_size)
        self.log_softmax = nn.LogSoftmax(dim=-1)


    def forward(self, src, tgt, src_mask=None, tgt_mask=None):
        # src, tgt: (seq_len, batch_size)
        src_emb = self.src_embedding(src) * math.sqrt(self.d_model)
        tgt_emb = self.tgt_embedding(tgt) * math.sqrt(self.d_model)
        src_emb = self.pos_encoder(src_emb)
        tgt_emb = self.pos_decoder(tgt_emb)
        output = self.transformer(src_emb, tgt_emb, src_mask=src_mask, tgt_mask=tgt_mask)
        output = self.fc_out(output)
        output = self.log_softmax(output)
        return output




def train_transformer(model, dataloader, optimizer, criterion, n_epochs):
    model.train()
    train_losses = []
    val_losses = []
    val_accuracies = []


    for epoch in range(n_epochs):
        total_loss = 0
        for input_tensor, target_tensor in dataloader:
            src = input_tensor[0].to(device)  # (src_seq_len,)
            tgt = target_tensor[0].to(device)  
            tgt_input = torch.cat([torch.tensor([word_to_index['SOS']], device=device), tgt[:-1]])  # Add SOS token


            src = src.unsqueeze(1)
            tgt_input = tgt_input.unsqueeze(1)
            tgt_output = tgt.unsqueeze(1)
            tgt_mask = generate_square_subsequent_mask(tgt_input.size(0)).to(device)
            optimizer.zero_grad()
            output = model(src, tgt_input, src_mask=None, tgt_mask=tgt_mask)
            output_dim = output.shape[-1]
            loss = criterion(output.view(-1, output_dim), tgt_output.view(-1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_train_loss = total_loss / len(dataloader)
        train_losses.append(avg_train_loss)


        # Assuming you have a validation loop (you can use the evaluate_transformer function here)
        # For now, using the same training loop for validation:
        val_loss, val_acc = evaluate_transformer(model, dataloader, criterion)
        val_losses.append(val_loss)
        val_accuracies.append(val_acc)
        print(f"Epoch {epoch+1:02d}: Training Loss = {avg_train_loss:.4f}, Validation Loss = {val_loss:.4f}, Validation Accuracy = {val_acc:.4f}")


    return train_losses, val_losses, val_accuracies




def evaluate_transformer(model, dataloader, criterion):
    model.eval()
    total_loss = 0
    correct_sentences = 0
    with torch.no_grad():
        for input_tensor, target_tensor in dataloader:
            src = input_tensor[0].to(device)
            tgt = target_tensor[0].to(device)
            src = src.unsqueeze(1)
            tgt_input = torch.tensor([word_to_index['SOS']], device=device).unsqueeze(1)
            output_sentence = []
            max_len = tgt.size(0)
            for di in range(max_len):
                tgt_mask = generate_square_subsequent_mask(tgt_input.size(0)).to(device)
                output = model(src, tgt_input, src_mask=None, tgt_mask=tgt_mask)
                next_token = output[-1, 0].argmax().item()
                output_sentence.append(next_token)
                tgt_input = torch.cat([tgt_input, torch.tensor([[next_token]], device=device)], dim=0)
                if next_token == EOS_token:
                    break


            tgt_input_for_loss = torch.cat([torch.tensor([word_to_index['SOS']], device=device), tgt[:-1]])
            tgt_input_for_loss = tgt_input_for_loss.unsqueeze(1)
            tgt_mask = generate_square_subsequent_mask(tgt_input_for_loss.size(0)).to(device)
            output_for_loss = model(src, tgt_input_for_loss, src_mask=None, tgt_mask=tgt_mask)
            output_dim = output_for_loss.shape[-1]
            loss = criterion(output_for_loss.view(-1, output_dim), tgt.unsqueeze(1).view(-1))
            total_loss += loss.item()


            if output_sentence == tgt.tolist():
                correct_sentences += 1
    avg_loss = total_loss / len(dataloader)
    accuracy = correct_sentences / len(dataloader)
    return avg_loss, accuracy




# -------------------------------
# Initialize Model, Optimizer, Loss Function
# -------------------------------
n_layers = 1
n_heads = 4
n_epochs = 300
d_model = 128


model = TransformerTranslationModel(vocab_size=len(word_to_index), d_model=d_model,
                                    nhead=n_heads, num_layers=n_layers).to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01)
criterion = nn.NLLLoss()


train_losses, val_losses, val_accuracies = train_transformer(model, dataloader, optimizer, criterion, n_epochs)


# -------------------------------
# Plotting Results
# -------------------------------
epochs = list(range(1, n_epochs+1))


plt.figure(figsize=(8, 6))
plt.plot(epochs, train_losses, label="Training Loss")
plt.plot(epochs, val_losses, label="Validation Loss", linestyle='--')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(8, 6))
plt.plot(epochs, val_accuracies, label="Validation Accuracy", color='green')
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Using device: cuda
# /home/sjim/anaconda3/envs/Jim1/lib/python3.12/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch 01: Training Loss = 5.4141, Validation Loss = 4.6641, Validation Accuracy = 0.0000
# Epoch 02: Training Loss = 4.5700, Validation Loss = 4.2231, Validation Accuracy = 0.0000
# Epoch 03: Training Loss = 4.1773, Validation Loss = 3.8008, Validation Accuracy = 0.0000
# Epoch 04: Training Loss = 3.7762, Validation Loss = 3.4195, Validation Accuracy = 0.0000
# Epoch 05: Training Loss = 3.4192, Validation Loss = 3.0844, Validation Accuracy = 0.0000
# Epoch 06: Training Loss = 3.1283, Validation Loss = 2.8045, Validation Accuracy = 0.0000
# Epoch 07: Training Loss = 2.8446, Validation Loss = 2.5422, Validation Accuracy = 0.0088
# Epoch 08: Training Loss = 2.5916, Validation Loss = 2.3487, Validation Accuracy = 0.0442
# Epoch 09: Training Loss = 2.3855, Validation Loss = 2.0783, Validation Accuracy = 0.0442
# Epoch 10: Training Loss = 2.1091, Validation Loss = 1.8400, Validation Accuracy = 0.1062
# Epoch 11: Training Loss = 1.8734, Validation Loss = 1.6204, Validation Accuracy = 0.2035
# Epoch 12: Training Loss = 1.6781, Validation Loss = 1.5369, Validation Accuracy = 0.2035
# Epoch 13: Training Loss = 1.5624, Validation Loss = 1.3068, Validation Accuracy = 0.3451
# Epoch 14: Training Loss = 1.3770, Validation Loss = 1.1916, Validation Accuracy = 0.4248
# Epoch 15: Training Loss = 1.2271, Validation Loss = 1.0297, Validation Accuracy = 0.5221
# Epoch 16: Training Loss = 1.0544, Validation Loss = 0.8807, Validation Accuracy = 0.6195
# Epoch 17: Training Loss = 0.9045, Validation Loss = 0.7463, Validation Accuracy = 0.6991
# Epoch 18: Training Loss = 0.7690, Validation Loss = 0.6328, Validation Accuracy = 0.7522
# Epoch 19: Training Loss = 0.6551, Validation Loss = 0.5404, Validation Accuracy = 0.8496
# Epoch 20: Training Loss = 0.5603, Validation Loss = 0.4601, Validation Accuracy = 0.8850
# Epoch 21: Training Loss = 0.4771, Validation Loss = 0.3933, Validation Accuracy = 0.9292
# Epoch 22: Training Loss = 0.4079, Validation Loss = 0.3383, Validation Accuracy = 0.9646
# Epoch 23: Training Loss = 0.3503, Validation Loss = 0.2905, Validation Accuracy = 0.9735
# Epoch 24: Training Loss = 0.3004, Validation Loss = 0.2520, Validation Accuracy = 0.9646
# Epoch 25: Training Loss = 0.2601, Validation Loss = 0.2193, Validation Accuracy = 0.9823
# Epoch 26: Training Loss = 0.2262, Validation Loss = 0.1926, Validation Accuracy = 0.9912
# Epoch 27: Training Loss = 0.1983, Validation Loss = 0.1703, Validation Accuracy = 0.9912
# Epoch 28: Training Loss = 0.1758, Validation Loss = 0.1525, Validation Accuracy = 0.9912
# Epoch 29: Training Loss = 0.1564, Validation Loss = 0.1363, Validation Accuracy = 0.9912
# Epoch 30: Training Loss = 0.1397, Validation Loss = 0.1230, Validation Accuracy = 0.9912
# Epoch 31: Training Loss = 0.1259, Validation Loss = 0.1117, Validation Accuracy = 0.9912
# Epoch 32: Training Loss = 0.1142, Validation Loss = 0.1020, Validation Accuracy = 0.9912
# Epoch 33: Training Loss = 0.1041, Validation Loss = 0.0937, Validation Accuracy = 0.9912
# Epoch 34: Training Loss = 0.0955, Validation Loss = 0.0866, Validation Accuracy = 0.9912
# Epoch 35: Training Loss = 0.0882, Validation Loss = 0.0803, Validation Accuracy = 1.0000
# Epoch 36: Training Loss = 0.0817, Validation Loss = 0.0748, Validation Accuracy = 0.9912
# Epoch 37: Training Loss = 0.0761, Validation Loss = 0.0700, Validation Accuracy = 0.9912
# Epoch 38: Training Loss = 0.0710, Validation Loss = 0.0657, Validation Accuracy = 1.0000
# Epoch 39: Training Loss = 0.0666, Validation Loss = 0.0618, Validation Accuracy = 1.0000
# Epoch 40: Training Loss = 0.0627, Validation Loss = 0.0584, Validation Accuracy = 0.9912
# Epoch 41: Training Loss = 0.0591, Validation Loss = 0.0553, Validation Accuracy = 1.0000
# Epoch 42: Training Loss = 0.0560, Validation Loss = 0.0525, Validation Accuracy = 1.0000
# Epoch 43: Training Loss = 0.0531, Validation Loss = 0.0499, Validation Accuracy = 0.9912
# Epoch 44: Training Loss = 0.0505, Validation Loss = 0.0476, Validation Accuracy = 0.9912
# Epoch 45: Training Loss = 0.0481, Validation Loss = 0.0455, Validation Accuracy = 1.0000
# Epoch 46: Training Loss = 0.0459, Validation Loss = 0.0435, Validation Accuracy = 1.0000
# Epoch 47: Training Loss = 0.0439, Validation Loss = 0.0417, Validation Accuracy = 1.0000
# Epoch 48: Training Loss = 0.0421, Validation Loss = 0.0401, Validation Accuracy = 1.0000
# Epoch 49: Training Loss = 0.0404, Validation Loss = 0.0385, Validation Accuracy = 1.0000
# Epoch 50: Training Loss = 0.0389, Validation Loss = 0.0371, Validation Accuracy = 1.0000
# Epoch 51: Training Loss = 0.0374, Validation Loss = 0.0358, Validation Accuracy = 1.0000
# Epoch 52: Training Loss = 0.0361, Validation Loss = 0.0345, Validation Accuracy = 1.0000
# Epoch 53: Training Loss = 0.0348, Validation Loss = 0.0334, Validation Accuracy = 1.0000
# Epoch 54: Training Loss = 0.0336, Validation Loss = 0.0323, Validation Accuracy = 1.0000
# Epoch 55: Training Loss = 0.0325, Validation Loss = 0.0313, Validation Accuracy = 1.0000
# Epoch 56: Training Loss = 0.0315, Validation Loss = 0.0303, Validation Accuracy = 1.0000
# Epoch 57: Training Loss = 0.0305, Validation Loss = 0.0294, Validation Accuracy = 1.0000
# Epoch 58: Training Loss = 0.0296, Validation Loss = 0.0286, Validation Accuracy = 1.0000
# Epoch 59: Training Loss = 0.0287, Validation Loss = 0.0278, Validation Accuracy = 1.0000
# Epoch 60: Training Loss = 0.0279, Validation Loss = 0.0270, Validation Accuracy = 1.0000
# Epoch 61: Training Loss = 0.0272, Validation Loss = 0.0263, Validation Accuracy = 1.0000
# Epoch 62: Training Loss = 0.0264, Validation Loss = 0.0256, Validation Accuracy = 1.0000
# Epoch 63: Training Loss = 0.0257, Validation Loss = 0.0249, Validation Accuracy = 1.0000
# Epoch 64: Training Loss = 0.0251, Validation Loss = 0.0243, Validation Accuracy = 1.0000
# Epoch 65: Training Loss = 0.0244, Validation Loss = 0.0237, Validation Accuracy = 1.0000
# Epoch 66: Training Loss = 0.0239, Validation Loss = 0.0232, Validation Accuracy = 1.0000
# Epoch 67: Training Loss = 0.0233, Validation Loss = 0.0226, Validation Accuracy = 1.0000
# Epoch 68: Training Loss = 0.0228, Validation Loss = 0.0221, Validation Accuracy = 1.0000
# Epoch 69: Training Loss = 0.0222, Validation Loss = 0.0216, Validation Accuracy = 1.0000
# Epoch 70: Training Loss = 0.0217, Validation Loss = 0.0212, Validation Accuracy = 1.0000
# Epoch 71: Training Loss = 0.0213, Validation Loss = 0.0207, Validation Accuracy = 1.0000
# Epoch 72: Training Loss = 0.0208, Validation Loss = 0.0203, Validation Accuracy = 1.0000
# Epoch 73: Training Loss = 0.0204, Validation Loss = 0.0199, Validation Accuracy = 1.0000
# Epoch 74: Training Loss = 0.0200, Validation Loss = 0.0195, Validation Accuracy = 1.0000
# Epoch 75: Training Loss = 0.0196, Validation Loss = 0.0191, Validation Accuracy = 1.0000
# Epoch 76: Training Loss = 0.0192, Validation Loss = 0.0188, Validation Accuracy = 1.0000
# Epoch 77: Training Loss = 0.0188, Validation Loss = 0.0184, Validation Accuracy = 1.0000
# Epoch 78: Training Loss = 0.0185, Validation Loss = 0.0181, Validation Accuracy = 1.0000
# Epoch 79: Training Loss = 0.0181, Validation Loss = 0.0177, Validation Accuracy = 1.0000
# Epoch 80: Training Loss = 0.0178, Validation Loss = 0.0174, Validation Accuracy = 1.0000
# Epoch 81: Training Loss = 0.0175, Validation Loss = 0.0171, Validation Accuracy = 1.0000
# Epoch 82: Training Loss = 0.0172, Validation Loss = 0.0168, Validation Accuracy = 1.0000
# Epoch 83: Training Loss = 0.0169, Validation Loss = 0.0166, Validation Accuracy = 1.0000
# Epoch 84: Training Loss = 0.0166, Validation Loss = 0.0163, Validation Accuracy = 1.0000
# Epoch 85: Training Loss = 0.0163, Validation Loss = 0.0160, Validation Accuracy = 1.0000
# Epoch 86: Training Loss = 0.0161, Validation Loss = 0.0158, Validation Accuracy = 1.0000
# Epoch 87: Training Loss = 0.0158, Validation Loss = 0.0155, Validation Accuracy = 1.0000
# Epoch 88: Training Loss = 0.0156, Validation Loss = 0.0153, Validation Accuracy = 1.0000
# Epoch 89: Training Loss = 0.0153, Validation Loss = 0.0151, Validation Accuracy = 1.0000
# Epoch 90: Training Loss = 0.0151, Validation Loss = 0.0148, Validation Accuracy = 1.0000
# Epoch 91: Training Loss = 0.0149, Validation Loss = 0.0146, Validation Accuracy = 1.0000
# Epoch 92: Training Loss = 0.0147, Validation Loss = 0.0144, Validation Accuracy = 1.0000
# Epoch 93: Training Loss = 0.0144, Validation Loss = 0.0142, Validation Accuracy = 1.0000
# Epoch 94: Training Loss = 0.0142, Validation Loss = 0.0140, Validation Accuracy = 1.0000
# Epoch 95: Training Loss = 0.0140, Validation Loss = 0.0138, Validation Accuracy = 1.0000
# Epoch 96: Training Loss = 0.0138, Validation Loss = 0.0136, Validation Accuracy = 1.0000
# Epoch 97: Training Loss = 0.0137, Validation Loss = 0.0134, Validation Accuracy = 1.0000
# Epoch 98: Training Loss = 0.0135, Validation Loss = 0.0133, Validation Accuracy = 1.0000
# Epoch 99: Training Loss = 0.0133, Validation Loss = 0.0131, Validation Accuracy = 1.0000
# Epoch 100: Training Loss = 0.0131, Validation Loss = 0.0129, Validation Accuracy = 1.0000
# Epoch 101: Training Loss = 0.0130, Validation Loss = 0.0128, Validation Accuracy = 1.0000
# Epoch 102: Training Loss = 0.0128, Validation Loss = 0.0126, Validation Accuracy = 1.0000
# Epoch 103: Training Loss = 0.0126, Validation Loss = 0.0124, Validation Accuracy = 1.0000
# Epoch 104: Training Loss = 0.0125, Validation Loss = 0.0123, Validation Accuracy = 1.0000
# Epoch 105: Training Loss = 0.0123, Validation Loss = 0.0121, Validation Accuracy = 1.0000
# Epoch 106: Training Loss = 0.0122, Validation Loss = 0.0120, Validation Accuracy = 1.0000
# Epoch 107: Training Loss = 0.0120, Validation Loss = 0.0119, Validation Accuracy = 1.0000
# Epoch 108: Training Loss = 0.0119, Validation Loss = 0.0117, Validation Accuracy = 1.0000
# Epoch 109: Training Loss = 0.0118, Validation Loss = 0.0116, Validation Accuracy = 1.0000
# Epoch 110: Training Loss = 0.0116, Validation Loss = 0.0115, Validation Accuracy = 1.0000
# Epoch 111: Training Loss = 0.0115, Validation Loss = 0.0113, Validation Accuracy = 1.0000
# Epoch 112: Training Loss = 0.0114, Validation Loss = 0.0112, Validation Accuracy = 1.0000
# Epoch 113: Training Loss = 0.0112, Validation Loss = 0.0111, Validation Accuracy = 1.0000
# Epoch 114: Training Loss = 0.0111, Validation Loss = 0.0110, Validation Accuracy = 1.0000
# Epoch 115: Training Loss = 0.0110, Validation Loss = 0.0109, Validation Accuracy = 1.0000
# Epoch 116: Training Loss = 0.0109, Validation Loss = 0.0107, Validation Accuracy = 1.0000
# Epoch 117: Training Loss = 0.0108, Validation Loss = 0.0106, Validation Accuracy = 1.0000
# Epoch 118: Training Loss = 0.0107, Validation Loss = 0.0105, Validation Accuracy = 1.0000
# Epoch 119: Training Loss = 0.0105, Validation Loss = 0.0104, Validation Accuracy = 1.0000
# Epoch 120: Training Loss = 0.0104, Validation Loss = 0.0103, Validation Accuracy = 1.0000
# Epoch 121: Training Loss = 0.0103, Validation Loss = 0.0102, Validation Accuracy = 1.0000
# Epoch 122: Training Loss = 0.0102, Validation Loss = 0.0101, Validation Accuracy = 1.0000
# Epoch 123: Training Loss = 0.0101, Validation Loss = 0.0100, Validation Accuracy = 1.0000
# Epoch 124: Training Loss = 0.0100, Validation Loss = 0.0099, Validation Accuracy = 1.0000
# Epoch 125: Training Loss = 0.0099, Validation Loss = 0.0098, Validation Accuracy = 1.0000
# Epoch 126: Training Loss = 0.0099, Validation Loss = 0.0097, Validation Accuracy = 1.0000
# Epoch 127: Training Loss = 0.0098, Validation Loss = 0.0097, Validation Accuracy = 1.0000
# Epoch 128: Training Loss = 0.0097, Validation Loss = 0.0096, Validation Accuracy = 1.0000
# Epoch 129: Training Loss = 0.0096, Validation Loss = 0.0095, Validation Accuracy = 1.0000
# Epoch 130: Training Loss = 0.0095, Validation Loss = 0.0094, Validation Accuracy = 1.0000
# Epoch 131: Training Loss = 0.0094, Validation Loss = 0.0093, Validation Accuracy = 1.0000
# Epoch 132: Training Loss = 0.0093, Validation Loss = 0.0092, Validation Accuracy = 1.0000
# Epoch 133: Training Loss = 0.0092, Validation Loss = 0.0092, Validation Accuracy = 1.0000
# Epoch 134: Training Loss = 0.0092, Validation Loss = 0.0091, Validation Accuracy = 1.0000
# Epoch 135: Training Loss = 0.0091, Validation Loss = 0.0090, Validation Accuracy = 1.0000
# Epoch 136: Training Loss = 0.0090, Validation Loss = 0.0089, Validation Accuracy = 1.0000
# Epoch 137: Training Loss = 0.0089, Validation Loss = 0.0089, Validation Accuracy = 1.0000
# Epoch 138: Training Loss = 0.0089, Validation Loss = 0.0088, Validation Accuracy = 1.0000
# Epoch 139: Training Loss = 0.0088, Validation Loss = 0.0087, Validation Accuracy = 1.0000
# Epoch 140: Training Loss = 0.0087, Validation Loss = 0.0086, Validation Accuracy = 1.0000
# Epoch 141: Training Loss = 0.0087, Validation Loss = 0.0086, Validation Accuracy = 1.0000
# Epoch 142: Training Loss = 0.0086, Validation Loss = 0.0085, Validation Accuracy = 1.0000
# Epoch 143: Training Loss = 0.0085, Validation Loss = 0.0084, Validation Accuracy = 1.0000
# Epoch 144: Training Loss = 0.0084, Validation Loss = 0.0084, Validation Accuracy = 1.0000
# Epoch 145: Training Loss = 0.0084, Validation Loss = 0.0083, Validation Accuracy = 1.0000
# Epoch 146: Training Loss = 0.0083, Validation Loss = 0.0082, Validation Accuracy = 1.0000
# Epoch 147: Training Loss = 0.0083, Validation Loss = 0.0082, Validation Accuracy = 1.0000
# Epoch 148: Training Loss = 0.0082, Validation Loss = 0.0081, Validation Accuracy = 1.0000
# Epoch 149: Training Loss = 0.0081, Validation Loss = 0.0081, Validation Accuracy = 1.0000
# Epoch 150: Training Loss = 0.0081, Validation Loss = 0.0080, Validation Accuracy = 1.0000
# Epoch 151: Training Loss = 0.0080, Validation Loss = 0.0079, Validation Accuracy = 1.0000
# Epoch 152: Training Loss = 0.0080, Validation Loss = 0.0079, Validation Accuracy = 1.0000
# Epoch 153: Training Loss = 0.0079, Validation Loss = 0.0078, Validation Accuracy = 1.0000
# Epoch 154: Training Loss = 0.0078, Validation Loss = 0.0078, Validation Accuracy = 1.0000
# Epoch 155: Training Loss = 0.0078, Validation Loss = 0.0077, Validation Accuracy = 1.0000
# Epoch 156: Training Loss = 0.0077, Validation Loss = 0.0077, Validation Accuracy = 1.0000
# Epoch 157: Training Loss = 0.0077, Validation Loss = 0.0076, Validation Accuracy = 1.0000
# Epoch 158: Training Loss = 0.0076, Validation Loss = 0.0076, Validation Accuracy = 1.0000
# Epoch 159: Training Loss = 0.0076, Validation Loss = 0.0075, Validation Accuracy = 1.0000
# Epoch 160: Training Loss = 0.0075, Validation Loss = 0.0075, Validation Accuracy = 1.0000
# Epoch 161: Training Loss = 0.0075, Validation Loss = 0.0074, Validation Accuracy = 1.0000
# Epoch 162: Training Loss = 0.0074, Validation Loss = 0.0074, Validation Accuracy = 1.0000
# Epoch 163: Training Loss = 0.0074, Validation Loss = 0.0073, Validation Accuracy = 1.0000
# Epoch 164: Training Loss = 0.0073, Validation Loss = 0.0073, Validation Accuracy = 1.0000
# Epoch 165: Training Loss = 0.0073, Validation Loss = 0.0072, Validation Accuracy = 1.0000
# Epoch 166: Training Loss = 0.0072, Validation Loss = 0.0072, Validation Accuracy = 1.0000
# Epoch 167: Training Loss = 0.0072, Validation Loss = 0.0071, Validation Accuracy = 1.0000
# Epoch 168: Training Loss = 0.0071, Validation Loss = 0.0071, Validation Accuracy = 1.0000
# Epoch 169: Training Loss = 0.0071, Validation Loss = 0.0070, Validation Accuracy = 1.0000
# Epoch 170: Training Loss = 0.0070, Validation Loss = 0.0070, Validation Accuracy = 1.0000
# Epoch 171: Training Loss = 0.0070, Validation Loss = 0.0070, Validation Accuracy = 1.0000
# Epoch 172: Training Loss = 0.0070, Validation Loss = 0.0069, Validation Accuracy = 1.0000
# Epoch 173: Training Loss = 0.0069, Validation Loss = 0.0069, Validation Accuracy = 1.0000
# Epoch 174: Training Loss = 0.0069, Validation Loss = 0.0068, Validation Accuracy = 1.0000
# Epoch 175: Training Loss = 0.0068, Validation Loss = 0.0068, Validation Accuracy = 1.0000
# Epoch 176: Training Loss = 0.0068, Validation Loss = 0.0067, Validation Accuracy = 1.0000
# Epoch 177: Training Loss = 0.0068, Validation Loss = 0.0067, Validation Accuracy = 1.0000
# Epoch 178: Training Loss = 0.0067, Validation Loss = 0.0067, Validation Accuracy = 1.0000
# Epoch 179: Training Loss = 0.0067, Validation Loss = 0.0066, Validation Accuracy = 1.0000
# Epoch 180: Training Loss = 0.0066, Validation Loss = 0.0066, Validation Accuracy = 1.0000
# Epoch 181: Training Loss = 0.0066, Validation Loss = 0.0066, Validation Accuracy = 1.0000
# Epoch 182: Training Loss = 0.0066, Validation Loss = 0.0065, Validation Accuracy = 1.0000
# Epoch 183: Training Loss = 0.0065, Validation Loss = 0.0065, Validation Accuracy = 1.0000
# Epoch 184: Training Loss = 0.0065, Validation Loss = 0.0064, Validation Accuracy = 1.0000
# Epoch 185: Training Loss = 0.0065, Validation Loss = 0.0064, Validation Accuracy = 1.0000
# Epoch 186: Training Loss = 0.0064, Validation Loss = 0.0064, Validation Accuracy = 1.0000
# Epoch 187: Training Loss = 0.0064, Validation Loss = 0.0063, Validation Accuracy = 1.0000
# Epoch 188: Training Loss = 0.0063, Validation Loss = 0.0063, Validation Accuracy = 1.0000
# Epoch 189: Training Loss = 0.0063, Validation Loss = 0.0063, Validation Accuracy = 1.0000
# Epoch 190: Training Loss = 0.0063, Validation Loss = 0.0062, Validation Accuracy = 1.0000
# Epoch 191: Training Loss = 0.0062, Validation Loss = 0.0062, Validation Accuracy = 1.0000
# Epoch 192: Training Loss = 0.0062, Validation Loss = 0.0062, Validation Accuracy = 1.0000
# Epoch 193: Training Loss = 0.0062, Validation Loss = 0.0061, Validation Accuracy = 1.0000
# Epoch 194: Training Loss = 0.0061, Validation Loss = 0.0061, Validation Accuracy = 1.0000
# Epoch 195: Training Loss = 0.0061, Validation Loss = 0.0061, Validation Accuracy = 1.0000
# Epoch 196: Training Loss = 0.0061, Validation Loss = 0.0060, Validation Accuracy = 1.0000
# Epoch 197: Training Loss = 0.0061, Validation Loss = 0.0060, Validation Accuracy = 1.0000
# Epoch 198: Training Loss = 0.0060, Validation Loss = 0.0060, Validation Accuracy = 1.0000
# Epoch 199: Training Loss = 0.0060, Validation Loss = 0.0060, Validation Accuracy = 1.0000
# Epoch 200: Training Loss = 0.0060, Validation Loss = 0.0059, Validation Accuracy = 1.0000
# Epoch 201: Training Loss = 0.0059, Validation Loss = 0.0059, Validation Accuracy = 1.0000
# Epoch 202: Training Loss = 0.0059, Validation Loss = 0.0059, Validation Accuracy = 1.0000
# Epoch 203: Training Loss = 0.0059, Validation Loss = 0.0058, Validation Accuracy = 1.0000
# Epoch 204: Training Loss = 0.0058, Validation Loss = 0.0058, Validation Accuracy = 1.0000
# Epoch 205: Training Loss = 0.0058, Validation Loss = 0.0058, Validation Accuracy = 1.0000
# Epoch 206: Training Loss = 0.0058, Validation Loss = 0.0058, Validation Accuracy = 1.0000
# Epoch 207: Training Loss = 0.0058, Validation Loss = 0.0057, Validation Accuracy = 1.0000
# Epoch 208: Training Loss = 0.0057, Validation Loss = 0.0057, Validation Accuracy = 1.0000
# Epoch 209: Training Loss = 0.0057, Validation Loss = 0.0057, Validation Accuracy = 1.0000
# Epoch 210: Training Loss = 0.0057, Validation Loss = 0.0057, Validation Accuracy = 1.0000
# Epoch 211: Training Loss = 0.0057, Validation Loss = 0.0056, Validation Accuracy = 1.0000
# Epoch 212: Training Loss = 0.0056, Validation Loss = 0.0056, Validation Accuracy = 1.0000
# Epoch 213: Training Loss = 0.0056, Validation Loss = 0.0056, Validation Accuracy = 1.0000
# Epoch 214: Training Loss = 0.0056, Validation Loss = 0.0055, Validation Accuracy = 1.0000
# Epoch 215: Training Loss = 0.0056, Validation Loss = 0.0055, Validation Accuracy = 1.0000
# Epoch 216: Training Loss = 0.0055, Validation Loss = 0.0055, Validation Accuracy = 1.0000
# Epoch 217: Training Loss = 0.0055, Validation Loss = 0.0055, Validation Accuracy = 1.0000
# Epoch 218: Training Loss = 0.0055, Validation Loss = 0.0054, Validation Accuracy = 1.0000
# Epoch 219: Training Loss = 0.0055, Validation Loss = 0.0054, Validation Accuracy = 1.0000
# Epoch 220: Training Loss = 0.0054, Validation Loss = 0.0054, Validation Accuracy = 1.0000
# Epoch 221: Training Loss = 0.0054, Validation Loss = 0.0054, Validation Accuracy = 1.0000
# Epoch 222: Training Loss = 0.0054, Validation Loss = 0.0054, Validation Accuracy = 1.0000
# Epoch 223: Training Loss = 0.0054, Validation Loss = 0.0053, Validation Accuracy = 1.0000
# Epoch 224: Training Loss = 0.0053, Validation Loss = 0.0053, Validation Accuracy = 1.0000
# Epoch 225: Training Loss = 0.0053, Validation Loss = 0.0053, Validation Accuracy = 1.0000
# Epoch 226: Training Loss = 0.0053, Validation Loss = 0.0053, Validation Accuracy = 1.0000
# Epoch 227: Training Loss = 0.0053, Validation Loss = 0.0052, Validation Accuracy = 1.0000
# Epoch 228: Training Loss = 0.0052, Validation Loss = 0.0052, Validation Accuracy = 1.0000
# Epoch 229: Training Loss = 0.0052, Validation Loss = 0.0052, Validation Accuracy = 1.0000
# Epoch 230: Training Loss = 0.0052, Validation Loss = 0.0052, Validation Accuracy = 1.0000
# Epoch 231: Training Loss = 0.0052, Validation Loss = 0.0052, Validation Accuracy = 1.0000
# Epoch 232: Training Loss = 0.0052, Validation Loss = 0.0051, Validation Accuracy = 1.0000
# Epoch 233: Training Loss = 0.0051, Validation Loss = 0.0051, Validation Accuracy = 1.0000
# Epoch 234: Training Loss = 0.0051, Validation Loss = 0.0051, Validation Accuracy = 1.0000
# Epoch 235: Training Loss = 0.0051, Validation Loss = 0.0051, Validation Accuracy = 1.0000
# Epoch 236: Training Loss = 0.0051, Validation Loss = 0.0051, Validation Accuracy = 1.0000
# Epoch 237: Training Loss = 0.0051, Validation Loss = 0.0050, Validation Accuracy = 1.0000
# Epoch 238: Training Loss = 0.0050, Validation Loss = 0.0050, Validation Accuracy = 1.0000
# Epoch 239: Training Loss = 0.0050, Validation Loss = 0.0050, Validation Accuracy = 1.0000
# Epoch 240: Training Loss = 0.0050, Validation Loss = 0.0050, Validation Accuracy = 1.0000
# Epoch 241: Training Loss = 0.0050, Validation Loss = 0.0050, Validation Accuracy = 1.0000
# Epoch 242: Training Loss = 0.0050, Validation Loss = 0.0049, Validation Accuracy = 1.0000
# Epoch 243: Training Loss = 0.0049, Validation Loss = 0.0049, Validation Accuracy = 1.0000
# Epoch 244: Training Loss = 0.0049, Validation Loss = 0.0049, Validation Accuracy = 1.0000
# Epoch 245: Training Loss = 0.0049, Validation Loss = 0.0049, Validation Accuracy = 1.0000
# Epoch 246: Training Loss = 0.0049, Validation Loss = 0.0049, Validation Accuracy = 1.0000
# Epoch 247: Training Loss = 0.0049, Validation Loss = 0.0048, Validation Accuracy = 1.0000
# Epoch 248: Training Loss = 0.0048, Validation Loss = 0.0048, Validation Accuracy = 1.0000
# Epoch 249: Training Loss = 0.0048, Validation Loss = 0.0048, Validation Accuracy = 1.0000
# Epoch 250: Training Loss = 0.0048, Validation Loss = 0.0048, Validation Accuracy = 1.0000
# Epoch 251: Training Loss = 0.0048, Validation Loss = 0.0048, Validation Accuracy = 1.0000
# Epoch 252: Training Loss = 0.0048, Validation Loss = 0.0048, Validation Accuracy = 1.0000
# Epoch 253: Training Loss = 0.0048, Validation Loss = 0.0047, Validation Accuracy = 1.0000
# Epoch 254: Training Loss = 0.0047, Validation Loss = 0.0047, Validation Accuracy = 1.0000
# Epoch 255: Training Loss = 0.0047, Validation Loss = 0.0047, Validation Accuracy = 1.0000
# Epoch 256: Training Loss = 0.0047, Validation Loss = 0.0047, Validation Accuracy = 1.0000
# Epoch 257: Training Loss = 0.0047, Validation Loss = 0.0047, Validation Accuracy = 1.0000
# Epoch 258: Training Loss = 0.0047, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 259: Training Loss = 0.0047, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 260: Training Loss = 0.0046, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 261: Training Loss = 0.0046, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 262: Training Loss = 0.0046, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 263: Training Loss = 0.0046, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 264: Training Loss = 0.0046, Validation Loss = 0.0046, Validation Accuracy = 1.0000
# Epoch 265: Training Loss = 0.0046, Validation Loss = 0.0045, Validation Accuracy = 1.0000
# Epoch 266: Training Loss = 0.0045, Validation Loss = 0.0045, Validation Accuracy = 1.0000
# Epoch 267: Training Loss = 0.0045, Validation Loss = 0.0045, Validation Accuracy = 1.0000
# Epoch 268: Training Loss = 0.0045, Validation Loss = 0.0045, Validation Accuracy = 1.0000
# Epoch 269: Training Loss = 0.0045, Validation Loss = 0.0045, Validation Accuracy = 1.0000
# Epoch 270: Training Loss = 0.0045, Validation Loss = 0.0045, Validation Accuracy = 1.0000
# Epoch 271: Training Loss = 0.0045, Validation Loss = 0.0044, Validation Accuracy = 1.0000
# Epoch 272: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 273: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 274: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 275: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 276: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 277: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 278: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 279: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 280: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 281: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 282: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 283: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 284: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 285: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 286: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 287: Training Loss = 0.0044, Validation Loss = 0.0044, Validation Accuracy = 0.9912
# Epoch 288: Training Loss = 0.0044, Validation Loss = 0.0043, Validation Accuracy = 0.9912
# Epoch 289: Training Loss = 0.0043, Validation Loss = 0.0043, Validation Accuracy = 0.9912
# Epoch 290: Training Loss = 0.0043, Validation Loss = 0.0043, Validation Accuracy = 0.9912
# Epoch 291: Training Loss = 0.0043, Validation Loss = 0.0043, Validation Accuracy = 0.9912
# Epoch 292: Training Loss = 0.0043, Validation Loss = 0.0043, Validation Accuracy = 0.9912
# Epoch 293: Training Loss = 0.0043, Validation Loss = 0.0042, Validation Accuracy = 0.9912
# Epoch 294: Training Loss = 0.0042, Validation Loss = 0.0042, Validation Accuracy = 0.9912
# Epoch 295: Training Loss = 0.0042, Validation Loss = 0.0042, Validation Accuracy = 0.9912
# Epoch 296: Training Loss = 0.0042, Validation Loss = 0.0042, Validation Accuracy = 0.9912
# Epoch 297: Training Loss = 0.0042, Validation Loss = 0.0042, Validation Accuracy = 0.9912
# Epoch 298: Training Loss = 0.0042, Validation Loss = 0.0042, Validation Accuracy = 0.9912
# Epoch 299: Training Loss = 0.0042, Validation Loss = 0.0041, Validation Accuracy = 0.9912
# Epoch 300: Training Loss = 0.0041, Validation Loss = 0.0041, Validation Accuracy = 0.9912
